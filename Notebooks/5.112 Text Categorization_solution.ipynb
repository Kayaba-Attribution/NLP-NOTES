# %% [markdown]
# ## Experimenting with text categorization

# %% [markdown]
# ### Step 1: Download and review the 20 Newsgroups corpus

# %%
# download the 20 newsgroups corpus
from sklearn.datasets import fetch_20newsgroups
data = fetch_20newsgroups()
data.target_names
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']

# %% [markdown]
# ### Step 2: choose a subset of the categories that you think will have minimal overlap
#     (fill in the blanks)

# %%
categories = ['comp.sys.ibm.pc.hardware', 'sci.crypt', 'rec.motorcycles', 'talk.politics.mideast']
train = fetch_20newsgroups(subset='train', categories=categories)
test = fetch_20newsgroups(subset='test', categories=categories)

# %% [markdown]
# ### Step 3: Build a pipeline with a MultinomialNB classifier

# %%
# convert to a numerical vector
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline

model = make_pipeline(TfidfVectorizer(), MultinomialNB())

# %% [markdown]
# ### Step 4: Apply your model to the training data, then predict labels for test data

# %%
model.fit(train.data, train.target)
labels = model.predict(test.data)

# %% [markdown]
# ### Step 5: Visualize the performance using a confusion matrix

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(test.target, labels)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False,
            xticklabels=train.target_names, yticklabels=train.target_names)
plt.xlabel('true label')
plt.ylabel('predicted label');

# %% [markdown]
# ### Step 6: Review the results. Did you manage to find any categories that were predicted with 100% accuracy?
# (if not, try different categories)
# Ans: it's tricky, although the 4 above comes very close with talk.politics.mideast having only 1 false negative

# %% [markdown]
# ### Step 7: Choose a subset of the categories that you think will have maximal overlap
#     (fill in the blanks)

# %%
categories = ['alt.atheism', 'soc.religion.christian', 'talk.religion.misc', 'talk.politics.mideast']
# categories = ['comp.os.ms-windows.misc', 'comp.sys.ibm.pc.hardware', 'comp.sys.mac.hardware', 'comp.windows.x']
train = fetch_20newsgroups(subset='train', categories=categories)
test = fetch_20newsgroups(subset='test', categories=categories)

# %% [markdown]
# ### Repeat steps 4-5 using your new categories. Did you manage to find any categories that were consistently misclassified? What does that suggest?

# %%
model.fit(train.data, train.target)
labels = model.predict(test.data)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(test.target, labels)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False,
            xticklabels=train.target_names, yticklabels=train.target_names)
plt.xlabel('true label')
plt.ylabel('predicted label');

# %% [markdown]
# Ans: Again it's tricky, although the 4 above comes close with soc.religion.christian being confused with alt.atheism and talk.religion.misc
